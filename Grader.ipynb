# %%
import time
import json
from datetime import datetime
from CanvasInterface import Course
#from AutoGrader.AutoGrader import Autograder
from NotebookGrader import Autograder
MINUTE = 60
HOUR = MINUTE*60
DAY = HOUR*24

'''
This grader script is the actual running process for grading the assignments.

It loads the course setting from config.json stored in the same folder.
This config contains all the information about when to start grading and stop grading
the assignments. The name of the master files etc. Look at the file, its very simple
'''

    

with open("configGrader.json","r") as f:
    conf = json.load(f)
# Out:
# Python version
# 3.11.9 (main, Apr  2 2024, 08:25:04) [Clang 15.0.0 (clang-1500.3.9.4)]
# Version info.
# sys.version_info(major=3, minor=11, micro=9, releaselevel='final', serial=0)
# /usr/local/opt/python@3.11/bin/python3.11

# %%
course = Course(API_URL=conf['API_URL'],API_KEY=conf['API_KEY'],COURSE_ID=conf['course'])

# %%
assignment_conf = conf['Assignments'][0]
assignment = [assignment for assignment in course.assignments if assignment.attributes['name'] == assignment_conf['name']][0]

auto = Autograder.makeAutoGrader(course,assignment,assignment_conf,conf,sharp=False)

# %%
[assignment.attributes['name'] for assignment in course.assignments]
# Out:
# ['Autograded assignment 1',
#  'Autograded assignment 2',
#  'Autograded assignment 3',
#  'Autograded assignment 4',
#  'Exam',
#  'ReExamJune2024',
#  'Group assignment 1',
#  'Group assignment 2',
#  'Group assignment 3']

# %%
response = course.getAssignmentSubmissions(course.assignments[0].attributes['id'])
# Out:
# Fetching assignment Autograded_assignment_1
# Assignments Fetched!

# %%
len(response)
# Out:
# 110

# %%
response.links['next']['url']
# Out:
# 'https://uppsala.instructure.com/api/v1/courses/112254/assignments/335755/submissions?page=2&per_page=50'

# %%
len([sub['submitted_at'] for sub in auto.submissions])
# Out:
# 100

# %%
auto._getSubmissions()
# Out:
# Fetching assignment Autograded_assignment_1
# Assignments Fetched!

# %%
test_sub = [sub for sub in auto.submissions if sub['user_id']==730733][0]

# %%
auto._gradeSubmission(test_sub)
# Out:
# Submission needs grading !
# Checking student Test Student, User_id 730733
# Downloading attachment Assignment_1_problem_solution.ipynb
# Grading nootebook!
# Preparing notebook for grading
# Loading notebook: StudentSubmission/730733_1.ipynb
# Loading notebook: GenerateMaterial/Assignments/Assignment_1_problem_TEST.ipynb
# Done preparing notebook for grading
# Writing student notebook with injected tests to variable
# Done writing student notebook with injected tests to variable
# Safe running notebook
# Error while fetching server API version: ('Connection aborted.', FileNotFoundError(2, 'No such file or directory'))
# (0,
#  "Error while fetching server API version: ('Connection aborted.', FileNotFoundError(2, 'No such file or directory'))",
#  True)
